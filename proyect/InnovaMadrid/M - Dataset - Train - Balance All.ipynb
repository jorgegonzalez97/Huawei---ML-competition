# %%
import pandas as pd
import csv
import numpy as np
import random
import pickle

# %%
pd.set_option('display.max_columns', None)

# %%
dtype_list=pickle.load(open('type/train.pkl','rb'))

# %%
#Path where the database is
path="../../dataset/train_data.csv"

#reading the database
df = pd.read_csv(path,header=0,dtype=dtype_list,delimiter='|')

# %%
df.label.value_counts()
# Out:
# 0    40461645
# 1     1445488
# Name: label, dtype: int64

# %%
df1=df[df.label==1].sample(frac=1)

# %%
del df

# %%
p=0.1

#Path where the database is
path="../../dataset/train_data.csv"

#reading the database
df = pd.read_csv(path,header=0, skiprows=lambda i: i>0 and random.random() > p,dtype=dtype_list,delimiter='|')

# %%
df.label.value_counts()
# Out:
# 0    4047847
# 1     145027
# Name: label, dtype: int64

# %%
df0=df[df.label==0].sample(frac=1).iloc[0:len(df1)]

# %%
del df

# %%
dffinal=df1.append(df0, ignore_index=True).sample(frac=1).reset_index(drop=True)

# %%
dffinal
# Out:
#          label      uid  task_id  adv_id  creat_type_cd  adv_prim_id  dev_id  \
# 0            0  2148336     2853    1347              7          147      29
# 1            1  1115467     5700    4569              6          118      60
# 2            0  2108714     2887    2213              7          185      12
# 3            1  1933373     3927    3434              6          156      56
# 4            1  1072245     3494    4779              7          193      37
# ...        ...      ...      ...     ...            ...          ...     ...
# 2890971      1  1268374     3854    3367              7          207      17
# 2890972      1  1333240     2727    1664              7          130      30
# 2890973      1  1738257     4335    5710              7          150      17
# 2890974      1  1532595     4658    3035              7          193      37
# 2890975      1  2227359     3649    1622              7          207      17
#
# ...

# %%
dffinal.label.value_counts()
# Out:
# 1    1445488
# 0    1445488
# Name: label, dtype: int64

# %%
dffinal.groupby('pt_d').label.mean()
# Out:
# pt_d
# 1    0.523847
# 2    0.506131
# 3    0.491122
# 4    0.490474
# 5    0.476560
# 6    0.502260
# 7    0.505593
# Name: label, dtype: float64

# %%
dffinal.to_csv('../../dataset/train_data_balance_todos.csv',index=False)
