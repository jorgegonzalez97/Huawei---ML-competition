# %%
import pandas as pd
import csv
import numpy as np
import random
import pickle

# %%
pd.set_option('display.max_columns', None)

# %%
dtype_list=pickle.load(open('type/train.pkl','rb'))

# %%
p=0.8

#Path where the database is
path="../../dataset/train_data.csv"

#reading the database
df = pd.read_csv(path,header=0, skiprows=lambda i: i>0 and random.random() > p,dtype=dtype_list,delimiter='|')

# %%
df.label.value_counts()
# Out:
# 0    32366498
# 1     1155968
# Name: label, dtype: int64

# %%
df1=df[df.label==1].sample(frac=1).iloc[0:1000000]

# %%
del df

# %%
p=0.1

#Path where the database is
path="../../dataset/train_data.csv"

#reading the database
df = pd.read_csv(path,header=0, skiprows=lambda i: i>0 and random.random() > p,dtype=dtype_list,delimiter='|')

# %%
df.label.value_counts()
# Out:
# 0    4046823
# 1     144128
# Name: label, dtype: int64

# %%
df0=df[df.label==0].sample(frac=1).iloc[0:1000000]

# %%
del df

# %%
dffinal=df1.append(df0, ignore_index=True)
dffinal=dffinal.sample(frac=1)

# %%
dffinal.head()
# Out:
#          label      uid  task_id  adv_id  creat_type_cd  adv_prim_id  dev_id  \
# 22390        1  1438110     4349    3955              7          119      19
# 1836943      0  1961583     5640    5956              7          144      60
# 475398       1  2134892     5861    6376              7          104      37
# 1325548      0  1597190     5079    3027              7          150      60
# 1791274      0  1967848     5745    5347              7          122      60
#
#          inter_type_cd  slot_id  spread_app_id  tags  app_first_class  \
# 22390                5       12             57    27                4
# 1836943              5       12             41    25                2
# 475398               5       16             50    37                4
# 1325548              5       13             11    39                2
# 1791274              5       11             56    18                2
#
#          app_second_class  age  city  city_rank  device_name  device_size  \
# ...

# %%
dffinal.label.value_counts()
# Out:
# 1    1000000
# 0    1000000
# Name: label, dtype: int64

# %%
dffinal.reset_index(inplace=True)
dffinal.drop(columns=['index'],inplace=True)

# %%
dffinal.head()
# Out:
#    label      uid  task_id  adv_id  creat_type_cd  adv_prim_id  dev_id  \
# 0      1  1438110     4349    3955              7          119      19
# 1      0  1961583     5640    5956              7          144      60
# 2      1  2134892     5861    6376              7          104      37
# 3      0  1597190     5079    3027              7          150      60
# 4      0  1967848     5745    5347              7          122      60
#
#    inter_type_cd  slot_id  spread_app_id  tags  app_first_class  \
# 0              5       12             57    27                4
# 1              5       12             41    25                2
# 2              5       16             50    37                4
# 3              5       13             11    39                2
# 4              5       11             56    18                2
#
#    app_second_class  age  city  city_rank  device_name  device_size  career  \
# ...

# %%
dffinal.to_csv('../../dataset/train_data_balance.csv',index=False)
