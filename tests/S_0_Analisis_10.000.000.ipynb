# %% [markdown]
# ![](files/images/EscUpmPolit_p.gif "UPM")

# %% [markdown]
# # Codigo Sergio Lopez

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import csv

# %% [markdown]
# ## Reading data

# %%
#Path where the database is
path="../dataset/train_data.csv"

#reading the database
df=pd.read_csv(path, delimiter='|',nrows=10000000)
df_original=df.copy()
df
# Out:
#          label      uid  task_id  adv_id  creat_type_cd  adv_prim_id  dev_id  \
# 0            0  1638254     2112    6869              7          207      17
# 1            0  1161786     3104    3247              7          183      29
# 2            0  1814783     5890    4183              7          178      17
# 3            0  1468996     1993    5405              7          207      17
# 4            0  2164010     5439    4677              2          138      24
# ...        ...      ...      ...     ...            ...          ...     ...
# 9999995      0  1615052     2101    5085              6          172      60
# 9999996      0  1459628     4735    6876              7          177      60
# 9999997      0  1869380     4100    2348              7          128      60
# 9999998      0  1640426     5876    2975              7          144      43
# 9999999      0  1385212     3401    1766              7          156      56
#
# ...

# %%
for column in df:
    print(column )
    print(len(df[column].unique()))
# Out:
# label
# 2
# uid
# 786900
# task_id
# 2940
# adv_id
# 3766
# creat_type_cd
# 8
# adv_prim_id
# 81
# dev_id
# 42
# inter_type_cd
# 3
# slot_id
# 12
# spread_app_id
# 55
# tags
# 27
# app_first_class
# 3
# app_second_class
# 18
# age
# 8
# city
# 344
# city_rank
# 4
# device_name
# 88
# device_size
# 184
# career
# 9
# gender
# 3
# net_type
# 5
# residence
# 36
# his_app_size
# 21
# his_on_shelf_time
# 4
# app_score
# 2
# emui_dev
# 17
# list_time
# 18
# device_price
# 7
# up_life_duration
# 21
# up_membership_grade
# 4
# membership_life_duration
# 16
# consume_purchase
# 9
# communication_onlinerate
# 1841
# communication_avgonline_30d
# 14
# indu_name
# 31
# pt_d
# 2

# %%
len(df["adv_id"].unique())
# Out:
# 3766

# %%
len(df["task_id"].unique())
# Out:
# 2940

# %%
len(df["creat_type_cd"].unique())
# Out:
# 8

# %%
len(df["dev_id"].unique())
# Out:
# 42

# %%
len(df["inter_type_cd"].unique())
# Out:
# 3

# %%
len(df["slot_id"].unique())
# Out:
# 12

# %%
len(df["spread_app_id"].unique())
# Out:
# 55

# %%
len(df["tags"].unique())
# Out:
# 27

# %%
len(df["app_first_class"].unique())
# Out:
# 3

# %%
df[df.adv_id==3829].head(50)
# Out:
#       label      uid  task_id  adv_id  creat_type_cd  adv_prim_id  dev_id  \
# 20        0  2202352     2530    3829              7          193      37
# 257       0  1532730     2530    3829              7          193      37
# 469       0  1243836     2530    3829              7          193      37
# 592       0  1544764     2530    3829              7          193      37
# 1016      0  1488458     2530    3829              7          193      37
# 1074      0  1497435     2530    3829              7          193      37
# 1087      0  1804630     2530    3829              7          193      37
# 1159      1  2174857     2530    3829              7          193      37
# 1244      0  1737314     2530    3829              7          193      37
# 1300      0  1996599     2530    3829              7          193      37
# 1308      0  2071035     2530    3829              7          193      37
# 1314      0  1455872     2530    3829              7          193      37
# ...

# %%
df_sort=df.sort_values('adv_id')
df_sort
# Out:
#         label      uid  task_id  adv_id  creat_type_cd  adv_prim_id  dev_id  \
# 766210      0  1658856     2233    1003              8          142      60
# 309752      0  1901996     2233    1003              8          142      60
# 57917       0  1809663     2233    1003              8          142      60
# 661826      0  1028309     2233    1003              8          142      60
# 683602      0  1255287     3537    1004              8          142      60
# ...       ...      ...      ...     ...            ...          ...     ...
# 565116      0  1379555     2529    7019              6          134      55
# 570781      0  1978432     2529    7019              7          134      55
# 594222      0  1867500     2529    7019              7          134      55
# 478210      0  1503140     2529    7019              7          134      55
# 126844      0  1339408     2529    7019              7          134      55
#
# ...

# %%
df_sort.iloc[0:50]
# Out:
#         label      uid  task_id  adv_id  creat_type_cd  adv_prim_id  dev_id  \
# 766210      0  1658856     2233    1003              8          142      60
# 309752      0  1901996     2233    1003              8          142      60
# 57917       0  1809663     2233    1003              8          142      60
# 661826      0  1028309     2233    1003              8          142      60
# 683602      0  1255287     3537    1004              8          142      60
# 27955       0  2053896     3537    1004              8          142      60
# 263991      0  1281057     5732    1005              7          108      26
# 644236      0  1679010     5732    1005              7          108      26
# 65498       0  1306058     5732    1005              7          108      26
# 551099      0  1660938     5732    1005              7          108      26
# 387402      0  1227412     5732    1005              7          108      26
# ...

# %%
df_sort.to_csv("dfsgbfediu.csv")

# %%
#Path where the database is
path="../dataset/train_data.csv"

#reading the database
d2f=pd.read_csv(path, delimiter='|',nrows=1000)
d2f
# Out:
#      label      uid  task_id  adv_id  creat_type_cd  adv_prim_id  dev_id  \
# 0        0  1638254     2112    6869              7          207      17
# 1        0  1161786     3104    3247              7          183      29
# 2        0  1814783     5890    4183              7          178      17
# 3        0  1468996     1993    5405              7          207      17
# 4        0  2164010     5439    4677              2          138      24
# ..     ...      ...      ...     ...            ...          ...     ...
# 995      0  2094931     4155    2618              8          174      68
# 996      0  1647308     3854    3367              7          207      17
# 997      0  1654443     2946    6698              7          110      38
# 998      0  1719276     4263    4691              7          137      37
# 999      0  1220598     3747    4461              7          207      17
#
#      inter_type_cd  slot_id  spread_app_id  ...  list_time  device_price  \
# ...

# %%
len(d2f["adv_id"].unique())
# Out:
# 405

# %%
len(d2f["task_id"].unique())
# Out:
# 399

# %%
d2f.sort_values('adv_id')
# Out:
#      label      uid  task_id  adv_id  creat_type_cd  adv_prim_id  dev_id  \
# 200      0  1929699     3348    1021              2          160      58
# 675      0  1546258     2306    1022              6          132      60
# 873      0  1483880     3942    1026              7          133      37
# 745      0  1202467     1665    1037              7          178      60
# 158      0  1719743     5770    1044              7          203      69
# ..     ...      ...      ...     ...            ...          ...     ...
# 566      0  1718124     5270    6908              7          147      29
# 543      0  2058411     5270    6908              7          147      29
# 227      0  1423210     5270    6908              7          147      29
# 945      0  1840887     4208    6941              7          115      54
# 621      0  1535369     1677    7016              6          167      37
#
#      inter_type_cd  slot_id  spread_app_id  ...  list_time  device_price  \
# ...

# %%
len(d2f["dev_id"].unique())
# Out:
# 36

# %%
for column in d2f:
    print(column )
    print(len(d2f[column].unique()))
# Out:
# label
# 2
# uid
# 993
# task_id
# 399
# adv_id
# 405
# creat_type_cd
# 8
# adv_prim_id
# 65
# dev_id
# 36
# inter_type_cd
# 3
# slot_id
# 11
# spread_app_id
# 47
# tags
# 23
# app_first_class
# 3
# app_second_class
# 16
# age
# 8
# city
# 236
# city_rank
# 4
# device_name
# 65
# device_size
# 23
# career
# 9
# gender
# 3
# net_type
# 3
# residence
# 33
# his_app_size
# 18
# his_on_shelf_time
# 4
# app_score
# 2
# emui_dev
# 13
# list_time
# 15
# device_price
# 6
# up_life_duration
# 16
# up_membership_grade
# 4
# membership_life_duration
# 3
# consume_purchase
# 8
# communication_onlinerate
# 30
# communication_avgonline_30d
# 12
# indu_name
# 29
# pt_d
# 1

# %%
df.corr()
# Out:
#                                 label       uid   task_id    adv_id  \
# label                        1.000000  0.015335  0.018545  0.016121
# uid                          0.015335  1.000000 -0.000618 -0.004067
# task_id                      0.018545 -0.000618  1.000000  0.022692
# adv_id                       0.016121 -0.004067  0.022692  1.000000
# creat_type_cd                0.022799  0.005870  0.067418  0.031206
# adv_prim_id                  0.073800  0.003663  0.027388  0.051723
# dev_id                      -0.048258 -0.009396 -0.023516 -0.086181
# inter_type_cd                0.027151  0.009849  0.030885  0.014748
# slot_id                     -0.058878  0.021992 -0.029394 -0.017044
# spread_app_id               -0.025406  0.011160 -0.139542 -0.030287
# tags                         0.025556  0.005792 -0.106073 -0.060851
# app_first_class              0.054177  0.020822 -0.036921  0.046824
# app_second_class            -0.028380  0.012441 -0.136746  0.039515
# ...
